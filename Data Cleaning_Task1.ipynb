# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
LoanData=pd.read_csv('loan_data.csv')

# %%
LoanData.head()
# Out:
#        Id  Gender Marital Status Family members Status of education  \
# 0  _RARE_    Male             No              0        Not Graduate
# 1  _RARE_  Female            Yes              0            Graduate
# 2  _RARE_  Female             No              1            Graduate
# 3  _RARE_    Male            Yes              0            Graduate
# 4  _RARE_    Male            Yes              0            Graduate
#
#   Self_Employed  Income of applicant  Income of coapplicant  \
# 0            No                 2265                   2292
# 1           Yes                 2150                   2674
# 2           NaN                 4120                      0
# 3            No                 8001                      0
# 4            No                 2797                   1713
#
#    LoanAmount applied for (in thoudands)  Loan_Amount_Duration  \
# 0                                   86.0                 360.0
# 1                                  110.0                 360.0
# ...

# %%
LoanData.shape
# Out:
# (1000, 13)

# %%
LoanData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 13 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   Id                                     1000 non-null   object
#  1   Gender                                 974 non-null    object
#  2   Marital Status                         1000 non-null   object
#  3   Family members                         976 non-null    object
#  4   Status of education                    1000 non-null   object
#  5   Self_Employed                          948 non-null    object
#  6   Income of applicant                    1000 non-null   int64
#  7   Income of coapplicant                  1000 non-null   int64
#  8   LoanAmount applied for (in thoudands)  955 non-null    float64
#  9   Loan_Amount_Duration                   970 non-null    float64
# ...

# %% [markdown]
# # Checking missing and null values

# %%
LoanData.isnull().sum()
# Out:
# Id                                        0
# Gender                                   26
# Marital Status                            0
# Family members                           24
# Status of education                       0
# Self_Employed                            52
# Income of applicant                       0
# Income of coapplicant                     0
# LoanAmount applied for (in thoudands)    45
# Loan_Amount_Duration                     30
# Credit_History                           75
# Property_Area                             0
# Loan_Status                               0
# dtype: int64

# %%
LoanData.describe()
# Out:
#        Income of applicant  Income of coapplicant  \
# count          1000.000000            1000.000000
# mean           4985.024000            1623.355000
# std            4117.207019            1957.376118
# min            1000.000000               0.000000
# 25%            2715.750000               0.000000
# 50%            3719.000000            1250.000000
# 75%            5652.500000            2469.000000
# max           33136.000000           10968.000000
#
#        LoanAmount applied for (in thoudands)  Loan_Amount_Duration  \
# count                             955.000000            970.000000
# mean                              140.621990            343.448454
# std                                74.612307             60.847149
# min                                30.000000             84.000000
# 25%                               100.000000            360.000000
# 50%                               125.000000            360.000000
# ...

# %% [markdown]
# # Removing unnecessary columns

# %%
LoanData.drop(["Id"], axis=1, inplace=True)

# %%
LoanData.head()
# Out:
#    Gender Marital Status Family members Status of education Self_Employed  \
# 0    Male             No              0        Not Graduate            No
# 1  Female            Yes              0            Graduate           Yes
# 2  Female             No              1            Graduate           NaN
# 3    Male            Yes              0            Graduate            No
# 4    Male            Yes              0            Graduate            No
#
#    Income of applicant  Income of coapplicant  \
# 0                 2265                   2292
# 1                 2150                   2674
# 2                 4120                      0
# 3                 8001                      0
# 4                 2797                   1713
#
#    LoanAmount applied for (in thoudands)  Loan_Amount_Duration  \
# 0                                   86.0                 360.0
# 1                                  110.0                 360.0
# ...

# %% [markdown]
# # Checking Duplicate Data

# %%
LoanData.duplicated().sum()
# Out:
# 0

# %%
## Expecting null values type

missing_value = ['N/a', 'na', np.nan]

# %%
LoanData=pd.read_csv('loan_data.csv', na_values=missing_value)

# %%
LoanData.isnull().sum()
# Out:
# Id                                        0
# Gender                                   26
# Marital Status                            0
# Family members                           24
# Status of education                       0
# Self_Employed                            52
# Income of applicant                       0
# Income of coapplicant                     0
# LoanAmount applied for (in thoudands)    45
# Loan_Amount_Duration                     30
# Credit_History                           75
# Property_Area                             0
# Loan_Status                               0
# dtype: int64

# %%
LoanData.isnull().any()
# Out:
# Id                                       False
# Gender                                    True
# Marital Status                           False
# Family members                            True
# Status of education                      False
# Self_Employed                             True
# Income of applicant                      False
# Income of coapplicant                    False
# LoanAmount applied for (in thoudands)     True
# Loan_Amount_Duration                      True
# Credit_History                            True
# Property_Area                            False
# Loan_Status                              False
# dtype: bool

# %%
sns.heatmap(LoanData.isnull(), yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
LoanData
# Out:
#          Id  Gender Marital Status Family members Status of education  \
# 0    _RARE_    Male             No              0        Not Graduate
# 1    _RARE_  Female            Yes              0            Graduate
# 2    _RARE_  Female             No              1            Graduate
# 3    _RARE_    Male            Yes              0            Graduate
# 4    _RARE_    Male            Yes              0            Graduate
# ..      ...     ...            ...            ...                 ...
# 995  _RARE_    Male            Yes              1            Graduate
# 996  _RARE_    Male             No              0            Graduate
# 997  _RARE_    Male             No              0        Not Graduate
# 998  _RARE_    Male             No              0            Graduate
# 999  _RARE_    Male            Yes              2        Not Graduate
#
#     Self_Employed  Income of applicant  Income of coapplicant  \
# 0              No                 2265                   2292
# ...

# %% [markdown]
# # Removing null values

# %%
LoanData.dropna(how='all')
# Out:
#          Id  Gender Marital Status Family members Status of education  \
# 0    _RARE_    Male             No              0        Not Graduate
# 1    _RARE_  Female            Yes              0            Graduate
# 2    _RARE_  Female             No              1            Graduate
# 3    _RARE_    Male            Yes              0            Graduate
# 4    _RARE_    Male            Yes              0            Graduate
# ..      ...     ...            ...            ...                 ...
# 995  _RARE_    Male            Yes              1            Graduate
# 996  _RARE_    Male             No              0            Graduate
# 997  _RARE_    Male             No              0        Not Graduate
# 998  _RARE_    Male             No              0            Graduate
# 999  _RARE_    Male            Yes              2        Not Graduate
#
#     Self_Employed  Income of applicant  Income of coapplicant  \
# 0              No                 2265                   2292
# ...

# %% [markdown]
# # Filling null values using-
# Backfill method,
# Forward method, and
# Interpolation

# %%
LoanData.fillna(method='ffill', inplace=True)

# %%
LoanData.head()
# Out:
#        Id  Gender Marital Status Family members Status of education  \
# 0  _RARE_    Male             No              0        Not Graduate
# 1  _RARE_  Female            Yes              0            Graduate
# 2  _RARE_  Female             No              1            Graduate
# 3  _RARE_    Male            Yes              0            Graduate
# 4  _RARE_    Male            Yes              0            Graduate
#
#   Self_Employed  Income of applicant  Income of coapplicant  \
# 0            No                 2265                   2292
# 1           Yes                 2150                   2674
# 2           Yes                 4120                      0
# 3            No                 8001                      0
# 4            No                 2797                   1713
#
#    LoanAmount applied for (in thoudands)  Loan_Amount_Duration  \
# 0                                   86.0                 360.0
# 1                                  110.0                 360.0
# ...

# %%
LoanData.isnull().sum()
# Out:
# Id                                       0
# Gender                                   0
# Marital Status                           0
# Family members                           0
# Status of education                      0
# Self_Employed                            0
# Income of applicant                      0
# Income of coapplicant                    0
# LoanAmount applied for (in thoudands)    0
# Loan_Amount_Duration                     0
# Credit_History                           1
# Property_Area                            0
# Loan_Status                              0
# dtype: int64

# %%
## Now Datasets has zero null value and it is ready for further process.
